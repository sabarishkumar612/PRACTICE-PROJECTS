# %% [markdown]
# # World Happiness Report Project

# %%
#IMPORTING THE REQUIRED LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#IMPORTING THE DATASET
ds1 = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
ds1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
ds1.shape
# Out:
# (158, 12)

# %% [markdown]
#   - Therefore the dataset has 158 rows and 12 columns.
#   - Among the 12 columns 'Country' and 'Region' have categorical data and all the other columns are having Numerical data
#   - According to the problem statement, the ‘Hapinees Score’ column is our target variable
#   - So the remaining 11 columns are our independent variables

# %%
#CHECHING FOR THE DATA TYPES OF EACH COLUMN
ds1.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#CHECKING FOR NULL VALUES
ds1.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Therefore the dataset has no null values

# %%
#CHECKING FOR THE COUNT OF EVERY VALUES IN EACH COULMNS
for i in ds1.columns:
    print(ds1[i].value_counts())
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# ...

# %% [markdown]
# From the above output we can confirm that the dataset doesn't have any white spaces or blank values

# %%
ds1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Therefore from the above output it is clear the dataset doesnot have any duplicated

# %%
ds1.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#SETTING "COUNTRY" COLUMN AS THE INDEX OF THE DATASET
ds1.set_index('Country',inplace=True)
ds1
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
#DELETING THE HAPPINESS RANK COUMN 
ds1.drop(['Happiness Rank'],axis=1,inplace=True)
ds1
# Out:
#                                       Region  Happiness Score  Standard Error  \
# Country
# Switzerland                   Western Europe            7.587         0.03411
# Iceland                       Western Europe            7.561         0.04884
# Denmark                       Western Europe            7.527         0.03328
# Norway                        Western Europe            7.522         0.03880
# Canada                         North America            7.427         0.03553
# ...                                      ...              ...             ...
# Rwanda                    Sub-Saharan Africa            3.465         0.03464
# Benin                     Sub-Saharan Africa            3.340         0.03656
# Syria        Middle East and Northern Africa            3.006         0.05015
# Burundi                   Sub-Saharan Africa            2.905         0.08658
# Togo                      Sub-Saharan Africa            2.839         0.06727
#
# ...

# %%
#SEPERATING CATEGORICAL AND NUMERICAL COLUMNS
cat_col=[]
num_col=[]
for i in ds1.dtypes.index:
    if ds1.dtypes[i]=="object":
        cat_col.append(i)
    else:
        num_col.append(i)
print(cat_col)
print(num_col)
# Out:
# ['Region']
# ['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
ds1.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# From the above output We can infer that
#
#     - There are no null values in the data set
#     - Mean is greater than median (50%) in columns like 'Standard Error', 'Trust','Generosity' and 'Dystopia Residual' which may result in Right Skewness
#     - Mean is less than Median (50%) in columns like 'Economy', 'Family', 'Health' and 'Freedom' which may result in left skewness
#     - There is no much difference between the 75% and the maximum value and so the outliers will not be there in the dataset

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
#COUNT PLOT FOR 'REGION' COLUMN
plt.figure(figsize=(6,6))
Region=['Sub Saharan Africa', 'Central & Eastern Europe', 'Latin America and Caribbean', 'Western Europe', 'Middle East and Northern Africa', 'Southeastern Asia', 'Southern Asia', 'Eastern Asia', 'Others']
share=[40,29,22,21,20,9,7,6,4]
colors=['orange','green','red','lightskyblue','coral','blue','pink','yellow','grey']
plt.style.use('ggplot')
plt.title('Region Count')
plt.pie(x=share,labels=Region,colors=colors,autopct='%.1f',startangle=90)
circle=plt.Circle(xy=(0,0), radius=0.75, facecolor='white')
plt.gca().add_artist(circle)
plt.show()

# %% [markdown]
# From the above plot we can infer that Sub-Sharan-Africa, Central and Eastern Europe, Latin America and Carribean and Western Europe have more Nations with higher Happiness score while Regions like North America, Australia and New Zeland have very less no.of Nations with higher happiness score

# %%
#DISTRIBUTION OF HAPPINESS SCORE
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(ds1['Happiness Score'])
plt.title('DISTRIBUTION OF HAPPINESS SCORE')
plt.show()

# %% [markdown]
# From the above plot it is clear that most of the happiness score is distributed around 5 and the curve is almost a bell shaped one, so that we can say that the data is normally distributed

# %%
''
# Out:
# ''

# %% [markdown]
# As we deducted eariler the data in "Standard Error" is skewed towards right

# %%
#ECONOMY [GDP PER CAPITA]
sns.set(rc={'figure.figsize':(6,6)})
sns.distplot(ds1['Economy (GDP per Capita)'],color='red',rug=True)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %% [markdown]
# The curve is almost normal ie. the data is normally distributed. Most of the nations are having their GDP per Capita around 1

# %%
#DISTRIBUTION OF FAMILY
plt.figure(figsize=(6,6))
sns.distplot(ds1['Family'])
plt.title('DISTRIBUTION OF FAMILY')
plt.show()

# %% [markdown]
# The data is skewed towards left as we predicted earlier and most of the values are nations are having valued distributed around 1

# %%
#DYSTOPIA RESIDUAL
sns.set(rc={'figure.figsize':(6,6)})
sns.kdeplot(ds1['Dystopia Residual'],shade=True,color='red')
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# The curve is almost bell shaped

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
#FREEDOM VS HAPPINESS SCORE
sns.set(style='whitegrid')
sns.scatterplot(x='Freedom',y='Happiness Score',color='orange',data=ds1)
plt.show()

# %%
#HEALTH VS HAPPINESS SCORE
sns.set(style='whitegrid')
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',color='green',data=ds1)
plt.show()

# %%
#Trust (Government Corruption) VS HAPPINESS SCORE
sns.set(style='whitegrid')
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',color='red',data=ds1)
plt.show()

# %%
#Economy (GDP per Capita) VS HAPPINESS SCORE
sns.set(style='whitegrid')
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',color='grey',data=ds1)
plt.show()

# %%
#Family VS HAPPINESS SCORE
sns.set(style='whitegrid')
sns.scatterplot(x='Family',y='Happiness Score',color='brown',data=ds1)
plt.show()

# %%
#Generosity VS HAPPINESS SCORE
sns.set(style='whitegrid')
sns.scatterplot(x='Generosity',y='Happiness Score',color='darkblue',data=ds1)
plt.show()

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(ds1,palette="spring_r")
plt.show()

# %%
#CHECKING FOR OUTLIERS
ds1.plot(kind='box',subplots=True,figsize=(10,10),layout=(3,3))
# Out:
# Happiness Score                     AxesSubplot(0.125,0.653529;0.227941x0.226471)
# Standard Error                   AxesSubplot(0.398529,0.653529;0.227941x0.226471)
# Economy (GDP per Capita)         AxesSubplot(0.672059,0.653529;0.227941x0.226471)
# Family                              AxesSubplot(0.125,0.381765;0.227941x0.226471)
# Health (Life Expectancy)         AxesSubplot(0.398529,0.381765;0.227941x0.226471)
# Freedom                          AxesSubplot(0.672059,0.381765;0.227941x0.226471)
# Trust (Government Corruption)           AxesSubplot(0.125,0.11;0.227941x0.226471)
# Generosity                           AxesSubplot(0.398529,0.11;0.227941x0.226471)
# Dystopia Residual                    AxesSubplot(0.672059,0.11;0.227941x0.226471)
# dtype: object

# %% [markdown]
# Outliers are there in columns such as Trust, Standard Error and Dystopia Residual

# %%
ds2=ds1.drop("Region",axis=1)
ds2
# Out:
#              Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Country
# Switzerland            7.587         0.03411                   1.39651
# Iceland                7.561         0.04884                   1.30232
# Denmark                7.527         0.03328                   1.32548
# Norway                 7.522         0.03880                   1.45900
# Canada                 7.427         0.03553                   1.32629
# ...                      ...             ...                       ...
# Rwanda                 3.465         0.03464                   0.22208
# Benin                  3.340         0.03656                   0.28665
# Syria                  3.006         0.05015                   0.66320
# Burundi                2.905         0.08658                   0.01530
# Togo                   2.839         0.06727                   0.20868
#
#               Family  Health (Life Expectancy)  Freedom  \
# Country
# ...

# %%
#CHECKING FOR OUTLIERS
from scipy.stats import zscore
z=np.abs(zscore(ds2))
z
# Out:
#              Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Country
# Switzerland         1.937360        0.805926                  1.369621
# Iceland             1.914581        0.055889                  1.135226
# Denmark             1.884792        0.854487                  1.192861
# Norway              1.880411        0.531526                  1.525130
# Canada              1.797179        0.722845                  1.194876
# ...                      ...             ...                       ...
# Rwanda              1.674055        0.774917                  1.552987
# Benin               1.783571        0.662582                  1.392303
# Syria               2.076199        0.132534                  0.455245
# Burundi             2.164688        2.263962                  2.067566
# Togo                2.222513        1.134182                  1.586334
#
#                Family  Health (Life Expectancy)   Freedom  \
# Country
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
#REMOVING OUTLIERS
ds11=ds1[(z<3).all(axis=1)]
ds11
# Out:
#                           Region  Happiness Score  Standard Error  \
# Country
# Switzerland       Western Europe            7.587         0.03411
# Iceland           Western Europe            7.561         0.04884
# Denmark           Western Europe            7.527         0.03328
# Norway            Western Europe            7.522         0.03880
# Canada             North America            7.427         0.03553
# ...                          ...              ...             ...
# Ivory Coast   Sub-Saharan Africa            3.655         0.05141
# Burkina Faso  Sub-Saharan Africa            3.587         0.04324
# Afghanistan        Southern Asia            3.575         0.03084
# Benin         Sub-Saharan Africa            3.340         0.03656
# Burundi       Sub-Saharan Africa            2.905         0.08658
#
#               Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                    1.39651  1.34951                   0.94143
# ...

# %%
#CHECKING FOR SKEWNESS
ds11.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11[['Family','Health (Life Expectancy)']] = np.square(ds11[['Family','Health (Life Expectancy)']])
ds11.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.239633
# Health (Life Expectancy)        -0.056315
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11[['Standard Error','Trust (Government Corruption)']] = np.cbrt(ds11[['Standard Error','Trust (Government Corruption)']])
ds11.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.239633
# Health (Life Expectancy)        -0.056315
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11[['Generosity']] = np.sqrt(ds11[['Generosity']])
ds11.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.239633
# Health (Life Expectancy)        -0.056315
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                      -0.285799
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# Therefore the skewness which was there in the dataset has been removed

# %%
# LABEL ENCODING TECHNIQUE
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_col:
    ds11[i]=le.fit_transform(ds11[i].astype(str))
ds11
# Out:
#               Region  Happiness Score  Standard Error  \
# Country
# Switzerland        9            7.587        0.324310
# Iceland            9            7.561        0.365532
# Denmark            9            7.527        0.321658
# Norway             9            7.522        0.338540
# Canada             5            7.427        0.328749
# ...              ...              ...             ...
# Ivory Coast        8            3.655        0.371834
# Burkina Faso       8            3.587        0.350990
# Afghanistan        7            3.575        0.313597
# Benin              8            3.340        0.331896
# Burundi            8            2.905        0.442391
#
#               Economy (GDP per Capita)    Family  Health (Life Expectancy)  \
# Country
# Switzerland                    1.39651  1.821177                  0.886290
# Iceland                        1.30232  1.966249                  0.898401
# ...

# %% [markdown]
# CHECKING FOR CORRELATION

# %%
ds11.corr()
# Out:
#                                  Region  Happiness Score  Standard Error  \
# Region                         1.000000        -0.145850       -0.047835
# Happiness Score               -0.145850         1.000000       -0.237228
# Standard Error                -0.047835        -0.237228        1.000000
# Economy (GDP per Capita)      -0.224928         0.773577       -0.244856
# Family                        -0.103790         0.750129       -0.183432
# Health (Life Expectancy)      -0.239975         0.762253       -0.326461
# Freedom                        0.101335         0.585066       -0.202292
# Trust (Government Corruption)  0.211246         0.394775       -0.095125
# Generosity                     0.307074         0.223529       -0.112971
# Dystopia Residual             -0.059494         0.528334        0.028798
#
#                                Economy (GDP per Capita)    Family  \
# Region                                        -0.224928 -0.103790
# ...

# %% [markdown]
# From the above output it is clear that independent variables like Economy(GDP per Capita), Family, Health, Freedom have high positive correlation with the target variable - Happiness
# score. Also there is a high probability for multicolinearity problem to exsist in this dataset

# %%
sns.heatmap(ds11.corr(),annot=True,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
#SEPERATING INDEPENDENT VARIABLES AND TARGET
x1 = ds11.drop('Happiness Score',axis=1)
y1 = ds11['Happiness Score']
print(x1)
# Out:
#               Region  Standard Error  Economy (GDP per Capita)    Family  \
# Country
# Switzerland        9        0.324310                   1.39651  1.821177
# Iceland            9        0.365532                   1.30232  1.966249
# Denmark            9        0.321658                   1.32548  1.851178
# Norway             9        0.338540                   1.45900  1.771428
# Canada             5        0.328749                   1.32629  1.749297
# ...              ...             ...                       ...       ...
# Ivory Coast        8        0.371834                   0.46534  0.594672
# Burkina Faso       8        0.350990                   0.25812  0.725700
# Afghanistan        7        0.313597                   0.31982  0.091718
# Benin              8        0.331896                   0.28665  0.125217
# Burundi            8        0.442391                   0.01530  0.172948
#
#               Health (Life Expectancy)  Freedom  \
# Country
# ...

# %%
y1
# Out:
# Country
# Switzerland     7.587
# Iceland         7.561
# Denmark         7.527
# Norway          7.522
# Canada          7.427
#                 ...
# Ivory Coast     3.655
# Burkina Faso    3.587
# Afghanistan     3.575
# Benin           3.340
# Burundi         2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
#SCALING TO REMOVE BIASNESS - STANDARD SCALING
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x1)
x1
# Out:
# array([[ 1.29683671, -0.91109675,  1.38191593, ...,  1.88683529,
#          0.62501384,  0.7568764 ],
#        [ 1.29683671,  0.28953441,  1.13832385, ...,  0.27941205,
#          1.51000403,  1.10929978],
#        [ 1.29683671, -0.98834276,  1.19821973, ...,  2.14203323,
#          0.92708818,  0.70850719],
#        ...,
#        [ 0.63509469, -1.22314025, -1.40259581, ..., -0.15304962,
#          1.07960711, -0.32213507],
#        [ 0.9659657 , -0.69014938, -1.48837933, ..., -0.35566049,
#         -0.27299692, -0.9307015 ],
#        [ 0.9659657 ,  2.52813796, -2.19013866, ..., -0.11531156,
#         -0.14429718, -0.54943602]])

# %%
x1=pd.DataFrame(data=x1)
x1
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.296837 -0.911097  1.381916  1.602804  1.516302  1.583704  1.886835
# 1    1.296837  0.289534  1.138324  1.916668  1.560193  1.338953  0.279412
# 2    1.296837 -0.988343  1.198220  1.667710  1.076692  1.476027  2.142033
# 3    1.296837 -0.496623  1.543526  1.495170  1.144110  1.611371  1.646273
# 4   -0.026647 -0.781797  1.200315  1.447290  1.276647  1.366887  1.477326
# ..        ...       ...       ...       ...       ...       ...       ...
# 144  0.965966  0.473095 -1.026255 -1.050756 -1.612309  0.274090  0.581308
# 145  0.965966 -0.134003 -1.562163 -0.767277 -1.429216 -0.216276  0.161899
# 146  0.635095 -1.223140 -1.402596 -2.138903 -1.362367 -1.285662 -0.153050
# 147  0.965966 -0.690149 -1.488379 -2.066428 -1.326836  0.379439 -0.355660
# 148  0.965966  2.528138 -2.190139 -1.963162 -1.514091 -2.054764 -0.115312
#
#             7         8
# 0    0.625014  0.756876
# 1    1.510004  1.109300
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif["features"] = x1.columns
vif
# Out:
#    VIF Factor  features
# 0    1.280759         0
# 1    1.150864         1
# 2    4.617395         2
# 3    2.083956         3
# 4    4.146855         4
# 5    1.980379         5
# 6    1.411891         6
# 7    1.472802         7
# 8    1.052302         8

# %% [markdown]
# From the above data frame it is clear that the dataset is free from multicolinearity problem

# %% [markdown]
# MODELLING

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=42)

# %%
#LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
m1=LinearRegression()
m1.fit(x1_train,y1_train)
trainprediction1=m1.predict(x1_train)
print(r2_score(y1_train,trainprediction1))
testprediction1=m1.predict(x1_test)
print(r2_score(y1_test,testprediction1))
score1=cross_val_score(m1,x1,y1)
print(score1)
print(score1.mean())
print((r2_score(y1_test,testprediction1)-(score1.mean())))
# Out:
# 0.9944227796556777
# 0.9965928722630757
# [0.96237357 0.85976167 0.79620929 0.62801829 0.9013552 ]
# 0.8295436016447848
# 0.1670492706182909

# %%
#ADA BOOST REGRESSION
from sklearn.ensemble import AdaBoostRegressor
m2=AdaBoostRegressor()
m2.fit(x1_train,y1_train)
trainprediction2=m2.predict(x1_train)
print(r2_score(y1_train,trainprediction2))
testprediction2=m2.predict(x1_test)
print(r2_score(y1_test,testprediction2))
score2=cross_val_score(m2,x1,y1)
print(score2)
print(score2.mean())
print((r2_score(y1_test,testprediction2)-(score2.mean())))
# Out:
# 0.9585085815433128
# 0.8594054472714788
# [-9.23002088 -6.18334024 -3.83235424 -5.66226161 -7.6744969 ]
# -6.516494773174344
# 7.375900220445823

# %%
#GRADIENT BOOST REGRESSION
from sklearn.ensemble import GradientBoostingRegressor
m3=AdaBoostRegressor()
m3.fit(x1_train,y1_train)
trainprediction3=m3.predict(x1_train)
print(r2_score(y1_train,trainprediction3))
testprediction3=m3.predict(x1_test)
print(r2_score(y1_test,testprediction3))
score3=cross_val_score(m3,x1,y1)
print(score3)
print(score3.mean())
print((r2_score(y1_test,testprediction3)-(score3.mean())))
# Out:
# 0.9574151843507126
# 0.8667767295852448
# [-10.13371338  -5.94123339  -3.4962108   -6.49476347  -8.07070626]
# -6.827325459119189
# 7.694102188704433

# %%
#RANDOM FOREST REGRESSION
from sklearn.ensemble import RandomForestRegressor
m4=RandomForestRegressor()
m4.fit(x1_train,y1_train)
trainprediction4=m4.predict(x1_train)
print(r2_score(y1_train,trainprediction4))
testprediction4=m4.predict(x1_test)
print(r2_score(y1_test,testprediction4))
score4=cross_val_score(m4,x1,y1)
print(score4)
print(score4.mean())
print((r2_score(y1_test,testprediction4)-(score4.mean())))
# Out:
# 0.9842066542601244
# 0.874274766322158
# [-8.11422152 -0.77879464 -0.80510612 -2.3628366  -6.21373919]
# -3.654939615061952
# 4.52921438138411

# %%
#DECISION TREE REGRESSION
from sklearn.tree import DecisionTreeRegressor
m5=DecisionTreeRegressor()
m5.fit(x1_train,y1_train)
trainprediction5=m5.predict(x1_train)
print(r2_score(y1_train,trainprediction5))
testprediction5=m5.predict(x1_test)
print(r2_score(y1_test,testprediction5))
score5=cross_val_score(m5,x1,y1)
print(score5)
print(score5.mean())
print((r2_score(y1_test,testprediction5)-(score5.mean())))
# Out:
# 1.0
# 0.8101766347703498
# [ -5.96960089  -9.5130496   -7.2166774  -11.64363026  -5.54128996]
# -7.976849623415515
# 8.787026258185865

# %%
#SVR
from sklearn.svm import SVR
m6=SVR()
m6.fit(x1_train,y1_train)
trainprediction6=m6.predict(x1_train)
print(r2_score(y1_train,trainprediction6))
testprediction6=m6.predict(x1_test)
print(r2_score(y1_test,testprediction6))
score6=cross_val_score(m6,x1,y1)
print(score6)
print(score6.mean())
print((r2_score(y1_test,testprediction6)-(score6.mean())))
# Out:
# 0.9838279246385683
# 0.9602046409371616
# [-11.09476334   0.27659935   0.74962692  -0.51756314  -5.08815075]
# -3.134850191475903
# 4.095054832413064

# %%
#KNN
from sklearn.neighbors import KNeighborsRegressor
m7=KNeighborsRegressor()
m7.fit(x1_train,y1_train)
trainprediction7=m7.predict(x1_train)
print(r2_score(y1_train,trainprediction7))
testprediction7=m7.predict(x1_test)
print(r2_score(y1_test,testprediction7))
score7=cross_val_score(m7,x1,y1)
print(score7)
print(score7.mean())
print((r2_score(y1_test,testprediction7)-(score7.mean())))
# Out:
# 0.9099492686599656
# 0.8864736144148475
# [-8.84288674 -1.55599755 -2.27503943 -8.07578254 -5.48710156]
# -5.247361561667272
# 6.13383517608212

# %%
#Lasso
from sklearn.linear_model import Lasso
m8=Lasso()
m8.fit(x1_train,y1_train)
trainprediction8=m8.predict(x1_train)
print(r2_score(y1_train,trainprediction8))
testprediction8=m8.predict(x1_test)
print(r2_score(y1_test,testprediction8))
score8=cross_val_score(m8,x1,y1)
print(score8)
print(score8.mean())
print((r2_score(y1_test,testprediction8)-(score8.mean())))
# Out:
# 0.0
# -0.09419444189554116
# [-42.37117014 -11.06215836  -0.30321946 -32.72956581 -29.0315447 ]
# -23.099531692553747
# 23.005337250658204

# %%
#Ridge
from sklearn.linear_model import Ridge
m9=Ridge()
m9.fit(x1_train,y1_train)
trainprediction9=m9.predict(x1_train)
print(r2_score(y1_train,trainprediction9))
testprediction9=m9.predict(x1_test)
print(r2_score(y1_test,testprediction9))
score9=cross_val_score(m9,x1,y1)
print(score9)
print(score9.mean())
print((r2_score(y1_test,testprediction9)-(score9.mean())))
# Out:
# 0.9943821325507771
# 0.9967166820770162
# [0.95679327 0.85323311 0.79478646 0.64395815 0.88651538]
# 0.8270572739196383
# 0.1696594081573779

# %%
#ExtraTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
m10=ExtraTreesRegressor()
m10.fit(x1_train,y1_train)
trainprediction10=m10.predict(x1_train)
print(r2_score(y1_train,trainprediction10))
testprediction10=m10.predict(x1_test)
print(r2_score(y1_test,testprediction10))
score10=cross_val_score(m10,x1,y1)
print(score10)
print(score10.mean())
print((r2_score(y1_test,testprediction10)-(score10.mean())))
# Out:
# 1.0
# 0.9231677000907287
# [-7.36628173 -0.09855305 -1.14718161 -1.52443061 -5.61814391]
# -3.1509181817494007
# 4.074085881840129

# %%
from sklearn.model_selection import GridSearchCV
parameters={'fit_intercept':[True,False],'n_jobs':[-1,1],'copy_X':[True,False],'positive':[True,False]}
gridsearchcv=GridSearchCV(LinearRegression(),parameters,cv=5)
gridsearchcv.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [-1, 1],
#                          'positive': [True, False]})

# %%
gridsearchcv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -1, 'positive': False}

# %%
best_model=LinearRegression(copy_X=True,fit_intercept=True,positive=False,n_jobs=-1)
best_model.fit(x1_train,y1_train)
prediction=best_model.predict(x1_test)
print(r2_score(y1_test,prediction))
# Out:
# 0.9965928722630757

# %%
#SAVING THE BEST MODEL
import joblib
joblib.dump(best_model,"world_happiness.obj")
# Out:
# ['world_happiness.obj']

# %%
reload=joblib.load('world_happiness.obj')
reload.predict(x1_test)
# Out:
# array([5.26498968, 6.99836763, 4.46469148, 5.17342243, 5.20165644,
#        6.48796774, 5.54675023, 3.70718278, 5.55048497, 5.06337373,
#        4.70380158, 7.25851518, 6.3890556 , 7.35643317, 6.85369323,
#        5.8668643 , 3.85065083, 5.51233182, 5.80032451, 4.11257245,
#        6.5575599 , 4.54392204, 6.70668069, 4.26176159, 4.21304085,
#        3.74331425, 4.58591641, 4.75635455, 5.953761  , 6.5150369 ,
#        6.7970713 , 6.98861165, 5.55670857, 7.29079524, 6.08449284,
#        4.73420969, 5.88450733, 6.65493873, 7.44654622, 6.36597946,
#        4.32234963, 5.15300902, 5.02358356, 6.94155777, 7.36763295])

# %%
def predict(happiness_score):
    happiness_score=happiness_score.reshape(1,-1)
    pred=best_model.predict(happiness_score)
    print(pred)
happiness_score=np.array([0.965966,0.473095,-1.026255,-1.050756,-1.612309,0.274090,0.581308,-0.106807,-1.343100])
predict(happiness_score)
# Out:
# [3.74331403]
